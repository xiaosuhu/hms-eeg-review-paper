# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../data_raw/train.csv') 
df["expert_consensus"].value_counts()
# Out:
# Seizure    20933
# GRDA       18861
# Other      18808
# GPD        16702
# LRDA       16640
# LPD        14856
# Name: expert_consensus, dtype: int64

# %%
import os
import sys
# sys.path.append(os.path.dirname("/Volumes/Franknano/Python_Project/HMS_EEG/project"))
sys.path.append(os.path.dirname("F:\Python_Project\HMS_EEG\project"))
from project.src.splits import make_holdout_and_inner_folds

# %%
tars = {'Seizure':0, 'LPD':1, 'GPD':2, 'LRDA':3, 'GRDA':4, 'Other':5}
df["label"] = df["expert_consensus"].map(tars).fillna(-1).astype(int)

# %%
df = make_holdout_and_inner_folds(df, y_col='label', group_col='patient_id', test_size=.2, seed=42)
df.head(20)
# Out:
#         eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0   1628180742           0                       0.0          353733
# 1   1628180742           1                       6.0          353733
# 2   1628180742           2                       8.0          353733
# 3   1628180742           3                      18.0          353733
# 4   1628180742           4                      24.0          353733
# 5   1628180742           5                      26.0          353733
# 6   1628180742           6                      30.0          353733
# 7   1628180742           7                      36.0          353733
# 8   1628180742           8                      40.0          353733
# 9   2277392603           0                       0.0          924234
# 10  2277392603           1                       2.0          924234
# 11   722738444           0                       0.0          999431
# 12   722738444           1                       2.0          999431
# ...

# %%
df["split"].value_counts()
# Out:
# trainval    83430
# test        23370
# Name: split, dtype: int64

# %%
df["inner_fold"].value_counts()
# Out:
# -1    23370
#  2    18184
#  0    17383
#  4    17179
#  3    16527
#  1    14157
# Name: inner_fold, dtype: int64

# %%
df.to_csv('../data_meta_splits/train_test_split.csv', index=False)
